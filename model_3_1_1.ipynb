# %%
import numpy as np
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---------------------------- ไว้ลบ Folder -------------------------------------

# %%
folder_to_delete = '/content/drive/MyDrive/dataset/DATASETPRO/REPASS'

# %%
folder_to_delete = '/content/drive/MyDrive/dataset/DATASETPRO/REWEAPON'

# %%
import shutil
shutil.rmtree(folder_to_delete)

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %%
from google.colab import drive #case mounted gdrive
drive.mount('/content/gdrive', force_remount=False)
# Out:
# Mounted at /content/gdrive

# %%
import os  #case connect via OS
os.chdir("/content/gdrive/")
os.getcwd()
# Out:
# '/content/gdrive'

# %%
path = "/content/gdrive/MyDrive/dataset/DATASETPRO"
files = os.listdir(path)
print(os.listdir(path))
# Out:
# ['WEAPON_KNIFE', 'PASS_NOKNIFE', 'REPASS', '.ipynb_checkpoints', 'REWEAPON']

# %%
categories1= []
filename_Weapon = os.listdir(path+"/WEAPON_KNIFE")
for filename in filename_Weapon:
        categories1.append(0)
df1 = pd.DataFrame({
    'filename': filename_Weapon,
    'category': categories1
})
categories2= []
filename_noneW = os.listdir(path+"/PASS_NOKNIFE")
for filename in filename_noneW:
        categories2.append(1)

df2 = pd.DataFrame({
    'filename': filename_noneW,
    'category': categories2
})

# %%
from PIL import Image
import os

def resize_batch(files, batch_size):
    for i in range(0, batch_size, batch_size):
        batch = files[i:i + batch_size]
        for item in batch:
            if os.path.isfile(path + '/WEAPON_KNIFE/' + item):
                im = Image.open(path + '/WEAPON_KNIFE/' + item)
                f, e = os.path.splitext(path + '/WEAPON_KNIFE/' + item)
                imResize = im.resize((200, 200), Image.ANTIALIAS)
                if imResize.mode != 'RGB':
                    imResize = imResize.convert('RGB')
                imResize.save(path + '/REWEAPON/' + item, 'JPEG', quality=90)
                print(imResize.size)

# ระบุพาธไปยังโฟลเดอร์
path = '/content/gdrive/MyDrive/dataset/DATASETPRO'

# รายการไฟล์ในโฟลเดอร์
filename_Weapon = os.listdir(path + '/WEAPON_KNIFE')

# จำนวนไฟล์ทั้งหมด
total_files = len(filename_Weapon)

# จำนวนไฟล์ที่ต้องการประมวลผล (ในที่นี้คือ 1000 ไฟล์)
desired_count = 1000

# เรียกใช้งาน resize_batch เพื่อประมวลผลไฟล์ทีละ 1000 ไฟล์
resize_batch(filename_Weapon, desired_count)
# Out:
# <ipython-input-24-bb9cb762a50b>:11: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   imResize = im.resize((200, 200), Image.ANTIALIAS)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# ...

# %%
from PIL import Image
import os

def resize_batch(files, batch_size):
    for i in range(0, batch_size, batch_size):
        batch = files[i:i + batch_size]
        for item in batch:
            if os.path.isfile(path + '/PASS_NOKNIFE/' + item):
                im = Image.open(path + '/PASS_NOKNIFE/' + item)
                f, e = os.path.splitext(path + '/PASS_NOKNIFE/' + item)
                imResize = im.resize((200, 200), Image.ANTIALIAS)
                if imResize.mode != 'RGB':
                    imResize = imResize.convert('RGB')
                imResize.save(path + '/REPASS/' + item, 'JPEG', quality=90)
                print(imResize.size)

# ระบุพาธไปยังโฟลเดอร์
path = '/content/gdrive/MyDrive/dataset/DATASETPRO'

# รายการไฟล์ในโฟลเดอร์
filename_noneW = os.listdir(path + '/PASS_NOKNIFE')

# จำนวนไฟล์ทั้งหมด
total_files = len(filename_noneW)

# จำนวนไฟล์ที่ต้องการประมวลผล (ในที่นี้คือ 1000 ไฟล์)
desired_count = 1000

# เรียกใช้งาน resize_batch เพื่อประมวลผลไฟล์ทีละ 1000 ไฟล์
resize_batch(filename_noneW, desired_count)
# Out:
# <ipython-input-25-4c425491fd48>:11: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   imResize = im.resize((200, 200), Image.ANTIALIAS)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# ...

# %%
from PIL import Image

# %%
pip install keras

# %%
pip install tensorflow

# %%
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array

# %%
X = np.empty([0])
y = np.empty([0])
filename_Weapon = os.listdir(path+"/REWEAPON")
filename_noneW = os.listdir(path+"/REPASS")
for filename in filename_Weapon:
    print(path+"/REWEAPON/"+filename)
    # load the image
    img = load_img(path+"/REWEAPON/"+filename)

    #print(type(img))
    #print(img.format)
    #print(img.mode)
    print(img.size)
    img.show()


     # convert to numpy array
    img_array = img_to_array(img)

    X = np.append (X,img_array)
    category = filename.split('.')[0]
    y = np.append(y,[0])

for filename in filename_noneW:
    print(path+"/REPASS/"+filename)
    # load the image
    img = load_img(path+"/REPASS/"+filename)

    #print(type(img))
    #print(img.format)
    #print(img.mode)
    print(img.size)
    img.show()


     # convert to numpy array
    img_array = img_to_array(img)

    X = np.append (X,img_array)
    category = filename.split('.')[0]
    y = np.append(y,[1])
# Out:
# /content/gdrive/MyDrive/dataset/DATASETPRO/REWEAPON/025377.jpg
# (200, 200)
# /content/gdrive/MyDrive/dataset/DATASETPRO/REWEAPON/035594.jpg
# (200, 200)
# /content/gdrive/MyDrive/dataset/DATASETPRO/REWEAPON/039913.jpg
# (200, 200)
# /content/gdrive/MyDrive/dataset/DATASETPRO/REWEAPON/025990.jpg
# (200, 200)
# /content/gdrive/MyDrive/dataset/DATASETPRO/REWEAPON/034143.jpg
# (200, 200)
# /content/gdrive/MyDrive/dataset/DATASETPRO/REWEAPON/042758.jpg
# (200, 200)
# /content/gdrive/MyDrive/dataset/DATASETPRO/REWEAPON/035086.jpg
# (200, 200)
# /content/gdrive/MyDrive/dataset/DATASETPRO/REWEAPON/035999.jpg
# (200, 200)
# /content/gdrive/MyDrive/dataset/DATASETPRO/REWEAPON/042548.jpg
# (200, 200)
# /content/gdrive/MyDrive/dataset/DATASETPRO/REWEAPON/034460.jpg
# (200, 200)
# /content/gdrive/MyDrive/dataset/DATASETPRO/REWEAPON/024312.jpg
# (200, 200)
# /content/gdrive/MyDrive/dataset/DATASETPRO/REWEAPON/010718.jpg
# (200, 200)
# ...

# %%
X = X.reshape(len(y),200,200,3)
x_vector = 200*200*3

# %%
X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=0.2, random_state=1000)
print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)
print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)

print(type(X_train))
print(type(y_train))

len_train  = len(X_train)
len_test = len(X_test)
# Out:
# X_train shape (1600, 200, 200, 3)
# y_train shape (1600,)
# X_test shape (400, 200, 200, 3)
# y_test shape (400,)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
X_train /= 255
X_test /= 255
print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)
print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (1600, 200, 200, 3)
# y_train shape (1600,)
# X_test shape (400, 200, 200, 3)
# y_test shape (400,)

# %%
X_train[1]

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPooling2D

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# สร้างโมเดล
model = models.Sequential()

# ชั้น Convolutional และ MaxPooling แรก
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(200, 200, 3)))
model.add(layers.MaxPooling2D((2, 2)))

# ชั้น Convolutional และ MaxPooling ที่สอง
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# ชั้น Convolutional และ MaxPooling ที่สาม
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# ชั้น Convolutional และ MaxPooling ที่สี่
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# ชั้น Convolutional และ MaxPooling ที่ห้า
model.add(layers.Conv2D(256, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# ทำการแปลงชั้น CNN เป็นลักษณะแบบเวกเตอร์
model.add(layers.Flatten())

# ชั้นแบบเชิงกลุ่ม (Dense Layer)
model.add(layers.Dense(512, activation='relu'))

# ชั้นสุดท้าย (output layer)
model.add(layers.Dense(2, activation='softmax'))

# คอมไพล์โมเดล
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, batch_size=32, epochs=10,validation_data = (X_test,y_test),callbacks =None)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 48s 950ms/step - loss: 0.4520 - accuracy: 0.7781 - val_loss: 0.3583 - val_accuracy: 0.8500
# Epoch 2/10
# 50/50 [==============================] - 46s 926ms/step - loss: 0.2450 - accuracy: 0.8981 - val_loss: 0.2027 - val_accuracy: 0.9225
# Epoch 3/10
# 50/50 [==============================] - 44s 889ms/step - loss: 0.1640 - accuracy: 0.9287 - val_loss: 0.1543 - val_accuracy: 0.9500
# Epoch 4/10
# 50/50 [==============================] - 42s 850ms/step - loss: 0.0960 - accuracy: 0.9631 - val_loss: 0.0900 - val_accuracy: 0.9625
# Epoch 5/10
# 50/50 [==============================] - 40s 811ms/step - loss: 0.1122 - accuracy: 0.9575 - val_loss: 0.1228 - val_accuracy: 0.9525
# Epoch 6/10
# 50/50 [==============================] - 42s 837ms/step - loss: 0.0604 - accuracy: 0.9762 - val_loss: 0.1170 - val_accuracy: 0.9675
# Epoch 7/10
# ...

# %%
print(history.history.keys())
plt.figure(figsize=(9,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'],loc = 'upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
test_loss, test_accuracy = model.evaluate(X_test,  y_test, verbose=2)

print('\nTest accuracy:', test_accuracy)
# Out:
# 13/13 - 3s - loss: 0.1070 - accuracy: 0.9725 - 3s/epoch - 195ms/step
#
# Test accuracy: 0.9725000262260437

# %% [markdown]
# **------------------------------------------**

# %%
class_names = ['Has_Weapon', 'Pass']

# %%
from sklearn.metrics import classification_report # tested with 0.21.2l
# Get Model Predictions for test data
prediction = model.predict(X_test)
# Predict the class based on the probability
predicted_class = (prediction> 0.5).astype("int32")
print(classification_report(y_test, predicted_class, target_names=class_names))
# Out:
# 13/13 [==============================] - 4s 284ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-a80690be8e96> in <cell line: 6>()
#       4 # Predict the class based on the probability
#       5 predicted_class = (prediction> 0.5).astype("int32")
# ----> 6 print(classification_report(y_test, predicted_class, target_names=class_names))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2308     """
#    2309
# -> 2310     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2311
#    2312     if labels is None:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      93
#      94     if len(y_type) > 1:
# ...

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, predicted_class)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-df1adef972c3> in <cell line: 3>()
#       1 from sklearn.metrics import confusion_matrix
#       2
# ----> 3 confusion_matrix(y_test, predicted_class)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     315     (0, 2, 1, 1)
#     316     """
# --> 317     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     318     if y_type not in ("binary", "multiclass"):
#     319         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      93
#      94     if len(y_type) > 1:
# ---> 95         raise ValueError(
# ...

# %%
from keras.optimizers import SGD
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential()

# ชั้น Convolutional และ MaxPooling แรก
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200, 200, 3)))
model.add(MaxPooling2D((2, 2)))

# ชั้น Convolutional และ MaxPooling ที่สอง
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

# ชั้น Convolutional และ MaxPooling ที่สาม
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

# ชั้น Convolutional และ MaxPooling ที่สี่
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

# ชั้น Convolutional และ MaxPooling ที่ห้า
model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

# ทำการแปลงชั้น CNN เป็นลักษณะแบบเวกเตอร์
model.add(Flatten())

# ชั้นแบบเชิงกลุ่ม (Dense Layer)
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))

# ชั้นสุดท้าย (output layer)
model.add(Dense(1, activation='sigmoid'))

# compile model
opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
history = model.fit(X_train, y_train, batch_size=32, epochs=10,validation_data = (X_test,y_test),callbacks =None)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 49s 952ms/step - loss: 0.7542 - accuracy: 0.5200 - val_loss: 0.6569 - val_accuracy: 0.5800
# Epoch 2/10
# 50/50 [==============================] - 44s 882ms/step - loss: 0.5926 - accuracy: 0.7163 - val_loss: 0.6864 - val_accuracy: 0.5425
# Epoch 3/10
# 50/50 [==============================] - 45s 893ms/step - loss: 0.6916 - accuracy: 0.5263 - val_loss: 0.6800 - val_accuracy: 0.5925
# Epoch 4/10
# 50/50 [==============================] - 44s 887ms/step - loss: 0.6190 - accuracy: 0.6637 - val_loss: 0.4009 - val_accuracy: 0.8625
# Epoch 5/10
# 50/50 [==============================] - 45s 893ms/step - loss: 0.4351 - accuracy: 0.8069 - val_loss: 0.2502 - val_accuracy: 0.9075
# Epoch 6/10
# 50/50 [==============================] - 44s 876ms/step - loss: 0.2282 - accuracy: 0.9162 - val_loss: 0.1410 - val_accuracy: 0.9450
# Epoch 7/10
# ...

# %%
test_loss, test_accuracy = model.evaluate(X_test,  y_test, verbose=2)

print('\nTest accuracy:', test_accuracy)
# Out:
# 13/13 - 3s - loss: 0.1002 - accuracy: 0.9625 - 3s/epoch - 228ms/step
#
# Test accuracy: 0.9624999761581421

# %%
print(history.history.keys())
plt.figure(figsize=(9,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'],loc = 'upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
from keras.optimizers import SGD
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

modelD = Sequential()

# ชั้น Convolutional และ MaxPooling แรก
modelD.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200, 200, 3)))
modelD.add(MaxPooling2D((2, 2)))
modelD.add(Dropout(0.2))  # Dropout เพิ่มเข้าไปในโมเดล

# ชั้น Convolutional และ MaxPooling ที่สอง
modelD.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
modelD.add(MaxPooling2D((2, 2)))
modelD.add(Dropout(0.2))  # Dropout เพิ่มเข้าไปในโมเดล

# ชั้น Convolutional และ MaxPooling ที่สาม
modelD.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
modelD.add(MaxPooling2D((2, 2)))
modelD.add(Dropout(0.2))  # Dropout เพิ่มเข้าไปในโมเดล

# ทำการแปลงชั้น CNN เป็นลักษณะแบบเวกเตอร์
modelD.add(Flatten())

# ชั้นแบบเชิงกลุ่ม (Dense Layer)
modelD.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
modelD.add(Dropout(0.5))  # Dropout เพิ่มเข้าไปในโมเดล

# ชั้นสุดท้าย (output layer)
modelD.add(Dense(1, activation='sigmoid'))

# compile model
opt = SGD(lr=0.001, momentum=0.9)
modelD.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
historyD = modelD.fit(X_train, y_train, batch_size=32, epochs=10,validation_data = (X_test,y_test),callbacks =None)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 45s 886ms/step - loss: 2.1756 - accuracy: 0.5263 - val_loss: 0.6930 - val_accuracy: 0.5100
# Epoch 2/10
# 50/50 [==============================] - 43s 871ms/step - loss: 0.6913 - accuracy: 0.5281 - val_loss: 0.6900 - val_accuracy: 0.7800
# Epoch 3/10
# 50/50 [==============================] - 43s 866ms/step - loss: 0.6903 - accuracy: 0.5225 - val_loss: 0.6916 - val_accuracy: 0.4900
# Epoch 4/10
# 50/50 [==============================] - 41s 829ms/step - loss: 0.6851 - accuracy: 0.5506 - val_loss: 0.6800 - val_accuracy: 0.8100
# Epoch 5/10
# 50/50 [==============================] - 42s 837ms/step - loss: 0.6478 - accuracy: 0.6319 - val_loss: 0.6445 - val_accuracy: 0.5425
# Epoch 6/10
# 50/50 [==============================] - 41s 830ms/step - loss: 0.6737 - accuracy: 0.5906 - val_loss: 0.6934 - val_accuracy: 0.4900
# Epoch 7/10
# ...

# %%
pip install visualkeras
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.0/993.0 kB 6.4 MB/s eta 0:00:00
# ...

# %%
import visualkeras

# %%
visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=928x1067>

# %%
from collections import defaultdict
color_map = defaultdict(dict)
color_map[Conv2D]['fill'] = 'orange'
color_map[MaxPooling2D]['fill'] = 'red'
color_map[Dense]['fill'] = 'pink'
color_map[Flatten]['fill'] = 'blue'
visualkeras.layered_view(model, legend=True,spacing=10, color_map=color_map)
# Out:
# <PIL.Image.Image image mode=RGBA size=928x1103>

# %%
tf.keras.Sequential([model,tf.keras.layers.Softmax()])
result = model.predict(X_test)
for i in range(5):
  print(np.argmax(result[i]))
# Out:
# 13/13 [==============================] - 3s 231ms/step
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# **------------------------------------------**

# %%
from tensorflow.keras.utils import array_to_img
image_show = array_to_img(X_test[3].reshape(200,200,3))
image_show
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
print(np.argmax(result[3])) #Has_Weapon = 0 , Pass = 1
resultx = np.argmax(result[3])
if resultx == 0:
  print("Has_Weapon")
else:
  print("Pass")
# Out:
# 0
# Has_Weapon

# %%
# load and prepare the image
def load_image(filename):
 # load the image
 img = load_img(filename, target_size=(200, 200))
 # convert to array
 img = img_to_array(img)
 # reshape into a single sample with 3 channels
 img = img.reshape(1, 200, 200, 3)
 # center pixel data
 img = img.astype('float32')
 img /= 255
 #img = img - [123.68, 116.779, 103.939]
 return img

# load an image and predict the class
def run_example():
 # load the image
 img = load_image_file('/content/gdrive/MyDrive/DataSetForXray')
 # predict the class
 result = model.predict(img)
 print(result)
 result_class = (result> 0.5).astype("int32")

 if result_class  == 0:
    print("Has_Weapon")
 else:
    print("Pass")

# entry point, run the example
run_example()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1639be958d6f> in <cell line: 30>()
#      28
#      29 # entry point, run the example
# ---> 30 run_example()
#
# <ipython-input-3-1639be958d6f> in run_example()
#      16 def run_example():
#      17  # load the image
# ---> 18  img = load_image_file('/content/gdrive/MyDrive/DataSetForXray')
#      19  # predict the class
#      20  result = model.predict(img)
#
# NameError: name 'load_image_file' is not defined
